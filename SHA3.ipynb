# %%
import hashlib

# %%
message = b"Hello ,World"

# %%
sha3_256 = hashlib.sha3_256()

sha3_256.update(message)
digest = sha3_256.digest()
hexdigest = digest .hex()

# %%
print(hexdigest)
# Out:
# f5d81d6ec92f62be33ecba75b77be4d68a3dff386300c2b664bb76a0a13c2bc1
