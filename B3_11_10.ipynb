# %%
# !pip install bitcoinlib
# Out:
# Collecting bitcoinlib
#   Downloading bitcoinlib-0.7.9-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.12/dist-packages (from bitcoinlib) (2.32.4)
# Collecting fastecdsa>=2.3.2 (from bitcoinlib)
#   Downloading fastecdsa-3.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pycryptodome>=3.20.0 (from bitcoinlib)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: SQLAlchemy>=2.0.20 in /usr/local/lib/python3.12/dist-packages (from bitcoinlib) (2.0.51)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->bitcoinlib) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->bitcoinlib) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->bitcoinlib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.0->bitcoinlib) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=2.0.20->bitcoinlib) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=2.0.20->bitcoinlib) (4.16.0)
# Downloading bitcoinlib-0.7.9-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 13.1 MB/s eta 0:00:00
# Downloading fastecdsa-3.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 34.3 MB/s eta 0:00:00
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 100.1 MB/s eta 0:00:00
# Installing collected packages: pycryptodome, fastecdsa, bitcoinlib
# Successfully installed bitcoinlib-0.7.9 fastecdsa-3.0.1 pycryptodome-3.23.0

# %%
# 3.11.10 Program to Create a Bitcoin Transaction and Sign It with senders private key
# Using the bitcoinlib Library

from bitcoinlib.transactions import Transaction
from bitcoinlib.keys import Key

print("Bitcoin UTXO Transaction Signing\n")

# Sender's private key
sender_private_key = Key()

# Sender and receiver addresses
sender_address = sender_private_key.address()
receiver_address = "1A1zP1eP5QGefi2DMPTfTL5SLmv7DivfNa"

# Existing UTXO being spent
previous_transaction_id = "1" * 64
previous_output_index = 0
previous_utxo_value = 150000

# Transaction amounts
receiver_amount = 100000
mining_fee = 1000

# Calculate sender's change
sender_change = (
    previous_utxo_value
    - receiver_amount
    - mining_fee
)

if sender_change < 0:
    raise ValueError("Insufficient UTXO value")

# Create transaction
bitcoin_transaction = Transaction()

# Add UTXO as transaction input
bitcoin_transaction.add_input(
    prev_txid=previous_transaction_id,
    output_n=previous_output_index
)

# Add receiver output
bitcoin_transaction.add_output(
    address=receiver_address,
    value=receiver_amount
)

# Add change output
if sender_change > 0:
    bitcoin_transaction.add_output(
        address=sender_address,
        value=sender_change
    )

# Sign transaction with sender's private key
bitcoin_transaction.sign(sender_private_key)

# Display transaction information
print("Transaction Details")
print("Sender Address       :", sender_address)
print("Receiver Address     :", receiver_address)

print("\nInput UTXO")
print("Previous TXID        :", previous_transaction_id)
print("Previous Output Index:", previous_output_index)
print("UTXO Value           :", previous_utxo_value, "satoshi")

print("\nTransaction Outputs")
print("Receiver Amount      :", receiver_amount, "satoshi")
print("Change Amount        :", sender_change, "satoshi")
print("Mining Fee           :", mining_fee, "satoshi")

print("\nValue Verification")
print("Input Value          :", previous_utxo_value, "satoshi")
print("Output Value         :", receiver_amount + sender_change, "satoshi")
print("Mining Fee           :", mining_fee, "satoshi")

print("\nSigned Transaction Hex")
print(bitcoin_transaction.raw_hex())
# Out:
# Bitcoin UTXO Transaction Signing
#
# Transaction Details
# Sender Address       : 1NonYEyopV12RBGJde7EpCKgCvFPehwb99
# Receiver Address     : 1A1zP1eP5QGefi2DMPTfTL5SLmv7DivfNa
#
# Input UTXO
# Previous TXID        : 1111111111111111111111111111111111111111111111111111111111111111
# Previous Output Index: 0
# UTXO Value           : 150000 satoshi
#
# Transaction Outputs
# Receiver Amount      : 100000 satoshi
# Change Amount        : 49000 satoshi
# Mining Fee           : 1000 satoshi
#
# Value Verification
# Input Value          : 150000 satoshi
# Output Value         : 149000 satoshi
# Mining Fee           : 1000 satoshi
#
# Signed Transaction Hex
# ...
